# %%
import pandas as pd

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/bibliography.csv")
data.head()
# Out:
#                                             pdf_name  \
# 0  (OCR) AfO 51, 2005-06, pp. 247-249 - Kryszat, ...
# 1  (OCR) CDOG 8, 2008, pp. 109-124 - Dercksen, J....
# 2  (OCR) JCS 59, 2007, pp. 93-106 - Larsen, Mogen...
# 3                           27_arastirma_3-libre.pdf
# 4                           28_arastirma_3-libre.pdf
#
#                                                title  \
# 0                                Kleine Mitteilungen
# 1                      The Assyrian Colony at Kanesh
# 2      Individual and Family in Old Assyrian Society
# 3  Ege-Akdeniz Bölgesi Sualtı Araştırması 2008 Yı...
# 4  Kültür Varlıkları ve Müzeler Genel Müdürlüğü A...
#
#                                               author author_place  \
# 0                                      Guido Kryszat        Mainz
# 1                                Jan Gerrit Dercksen       Leiden
# 2                               Mogens Trolle Larsen   Copenhagen
# ...

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/eBL_Dictionary.csv")
data.head()
# Out:
#       word                                         definition derived_from
# 0     -a I                           "my" (1 sg. pron. suff.)     cf. -ī I
# 1    -am I  "to me" (1 sg. dat. suff.) 2. vent. affix (cf....          NaN
# 2  -atti I                     (adv. endings) (cf. GAG §113l)          NaN
# 3    -iš I  "to; like" term.-adv. suffix on subst.s and ad...          NaN
# 4    -ka I       "you" (2 m. sg. acc. suff.) (cf. GAG p.258b)          NaN

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/OA_Lexicon_eBL.csv")
data.head()
# Out:
#    type          form         norm      lexeme  \
# 0  word   áb ša-ra-ni   ab šarrānē  ab šarrānē
# 1  word  áb ša-ra-nim  ab šarrānem  ab šarrānē
# 2  word  áb-ša-ra-nim  ab šarrānem  ab šarrānē
# 3  word   áb-ša-ra-ni   ab šarrānē  ab šarrānē
# 4  word  áb-ša-ra-ni₇   ab šarrānē  ab šarrānē
#
#                                                  eBL I_IV  A_D Female(f)  \
# 0  https://www.ebl.lmu.de/dictionary?word=ab šarrānē  NaN  NaN       NaN
# 1  https://www.ebl.lmu.de/dictionary?word=ab šarrānē  NaN  NaN       NaN
# 2  https://www.ebl.lmu.de/dictionary?word=ab šarrānē  NaN  NaN       NaN
# 3  https://www.ebl.lmu.de/dictionary?word=ab šarrānē  NaN  NaN       NaN
# 4  https://www.ebl.lmu.de/dictionary?word=ab šarrānē  NaN  NaN       NaN
#
#   Alt_lex
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/publications.csv")
data.head()
# Out:
#                                             pdf_name  page  \
# 0  (OCR) AfO 51, 2005-06, pp. 247-249 - Kryszat, ...     1
# 1  (OCR) AfO 51, 2005-06, pp. 247-249 - Kryszat, ...     2
# 2  (OCR) AfO 51, 2005-06, pp. 247-249 - Kryszat, ...     1
# 3  (OCR) AfO 51, 2005-06, pp. 247-249 - Kryszat, ...     2
# 4  (OCR) CDOG 8, 2008, pp. 109-124 - Dercksen, J....     1
#
#                                            page_text  has_akkadian
# 0  Kleine Mitteilungen\nAltassyrische Miszellen 2...         False
# 1  248\nKleine Mitteilungen\nKleine Mitteilungen\...         False
# 2  Kleine Mitteilungen\nAltassyrische Miszellen 2...         False
# 3  248\nKleine Mitteilungen\nKleine Mitteilungen\...         False
# 4  THE AssYRIAN COLONY AT KANEsH\nJan Gerrit Derc...         False

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/published_texts.csv")
data.head()
# Out:
#                                 oare_id  \
# 0  bd4b7138-70d5-490d-8234-299b0a75d3a3
# 1  b05376c2-fc3d-49f8-9792-a25c0df9c383
# 2  80547963-f2a2-4d5d-9544-fc7ada60d3b2
# 3  8c0d4238-f795-4061-8b3c-8469a66d86d6
# 4  2c0d870b-cd5e-fc36-8d81-114ecc7a9ac4
#
#                                    online transcript  cdli_id  \
# 0  https://oare.byu.edu/epigraphies/bd4b7138-70d5...  P361099
# 1  https://oare.byu.edu/epigraphies/b05376c2-fc3d...  P359543
# 2  https://oare.byu.edu/epigraphies/80547963-f2a2...  P361681
# 3  https://oare.byu.edu/epigraphies/8c0d4238-f795...  P361098
# 4  https://oare.byu.edu/epigraphies/2c0d870b-cd5e...  P290300
#
#                    aliases                                   label  \
# 0                 MP 1 bis              Cuneiform Tablet RA 60 125
# 1                ICK 1 146              Cuneiform Tablet ICK 1 146
# 2  TrMA 1 | Or 36 396 n. 2           Cuneiform Tablet Or 36 396A.2
# 3                     MP 1              Cuneiform Tablet RA 60 123
# ...

# %%
import pandas as pd

# 读取原始 CSV
input_file = "../deep-past-initiative-machine-translation/publications.csv"
output_file = "publications.csv"

# 截取前 5000 行
df = pd.read_csv(input_file).head(1000)

# 保存到新的 CSV 文件
df.to_csv(output_file, index=False)

print(f"已保存前 1000 行到 {output_file}")
# Out:
# 已保存前 1000 行到 publications.csv

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/train.csv")
data.head()
# Out:
#                                 oare_id  \
# 0  004a7dbd-57ce-46f8-9691-409be61c676e
# 1  0064939c-59b9-4448-a63d-34612af0a1b5
# 2  0073f2c0-524c-4bbf-915a-8c1772a4fb98
# 3  009fb838-8038-42bc-ad34-5f795b3840ee
# 4  00aa1c55-c80c-4346-a159-73ad43ab0ff7
#
#                                      transliteration  \
# 0  KIŠIB ma-nu-ba-lúm-a-šur DUMU ṣí-lá-{d}IM KIŠI...
# 1               1 TÚG ša qá-tim i-tur₄-DINGIR il₅-qé
# 2  TÚG u-la i-dí-na-ku-um i-tù-ra-ma 9 GÍN KÙ.BABBAR
# 3  KIŠIB šu-{d}EN.LÍL DUMU šu-ku-bi-im KIŠIB ṣí-l...
# 4  um-ma šu-ku-tum-ma a-na IŠTAR-lá-ma-sí ù ni-ta...
#
#                                          translation
# 0  Seal of Mannum-balum-Aššur son of Ṣilli-Adad, ...
# 1  Itūr-ilī has received one textile of ordinary ...
# 2  <gap> he did not give you a textile. He return...
# 3  Seal of Šu-Illil son of Šu-Kūbum, seal of Ṣilū...
# 4  From Šukkutum to Ištar-lamassī and Nitahšušar:...

# %%
data = pd.read_csv("../deep-past-initiative-machine-translation/Sentences_Oare_FirstWord_LinNum.csv")
data.head()
# Out:
#              display_name                             text_uuid  \
# 0   (Adana 237a) envelope  871e7671-e26b-4808-9acb-1c4a7e1ed2e6
# 1            (Adana 237s)  09260971-37a9-4b91-aa30-ff59322598e5
# 2               (HS 2931)  a5abb045-e25a-469a-90b3-89a49091b7be
# 3               (HS 2931)  a5abb045-e25a-469a-90b3-89a49091b7be
# 4               (HS 2931)  a5abb045-e25a-469a-90b3-89a49091b7be
#
#                           sentence_uuid  sentence_obj_in_text  \
# 0  f98879ad-d891-4602-8443-965baab6845d                     3
# 1  e3444ecf-0276-4e5a-90cb-1e08e9d9f65e                     3
# 2  cb7f723d-6e52-454d-8ca2-50863cab81cb                    10
# 3  5dc308e4-1033-4200-8b8b-6626d155539c                    20
# 4  49ae0d28-4916-4744-b316-607432f9b091                    23
#
#                                          translation first_word_transcription  \
# 0                Seal: trading station of Šalatiwar.                      NaN
# ...
